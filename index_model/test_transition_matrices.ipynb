# %%
include("../index_model/model.jl")
# Out:
# init (generic function with 1 method)

# %%
include("derived_parameters.jl")

p_low = 0.05 # positives 
pr = 1.0
re = 0.5
p_stay = 0.5

joint_transition(p_low,pr, re, p_stay)
# Out:
# 4×4 Matrix{Float64}:
#  0.95   0.95   0.4875  0.4875
#  0.0    0.0    0.0125  0.0125
#  0.025  0.025  0.4875  0.4875
#  0.025  0.025  0.0125  0.0125

# %%
25

# %%
p_index

# %%
M=4
sum(T[[2,4],M])
# Out:
# 0.5

# %%
T = [(1-fpr)*(1-p_start) (1-fpr)*(1-p_start) (1-fpr)*(1-p_stay) (1-fpr)*(1-p_stay);
     fpr * (1-p_start)   fpr * (1-p_start)  fpr*(1-p_stay)     fpr*(1-p_stay)     ;
     (1-tpr)*p_start     (1-tpr)*p_start    (1-fpr)*p_stay     (1-fpr)*p_stay     ;
     tpr*p_start         tpr*p_start        fpr*p_stay         fpr*p_stay         ]
