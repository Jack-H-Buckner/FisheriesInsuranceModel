# %%
using Pkg 
Pkg.activate("../.")
include("../src/model.jl")
include("../src/analysis.jl")

## Calculate value differnces for all models
# value_diffs("no_RA_short")
# value_diffs("no_RA_intermidiate")
# value_diffs("no_RA_long")

# value_diffs("RA_short")
# value_diffs("RA_intermidiate")
# value_diffs("RA_long")

# %%
println(VERSION)
println("Current environment: ", Base.active_project())
# Out:
# 1.10.5
# Current environment: /Users/johnbuckner/github/FisheriesInsuranceModel/Project.toml

# %%
include("../src/analysis.jl")
value_diffs("no_RA_intermidiate_lower_blimit")
# Out:
#   Activating project at `~/github/FisheriesInsuranceModel`

# %%
value_diffs("RA_intermidiate_lower_blimit")

# %%
ValueFunctionIterations.RandomVariableFunction
# Out:
# ValueFunctionIterations.RandomVariableFunction
